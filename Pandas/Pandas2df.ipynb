# %%
import numpy as np
import pandas as pd

# %%
# Using List

student = [

    ['Uday','Mansi'],
    [80,100],
    [10,12]
]

# %%
pd.DataFrame(student,columns=['student_name1','student_name2'])
# Out:
#   student_name1 student_name2
# 0          Uday         Mansi
# 1            80           100
# 2            10            12

# %%
movie = pd.read_csv('movies.csv',index_col='title_x')
ipl = pd.read_csv('ipl-matches.csv')

# %%
movie.shape , ipl.shape
# Out:
# ((1629, 17), (950, 20))

# %%
movie.dtypes
# Out:
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
movie.columns
# Out:
# Index(['imdb_id', 'poster_path', 'wiki_link', 'title_y', 'original_title',
#        'is_adult', 'year_of_release', 'runtime', 'genres', 'imdb_rating',
#        'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1629 entries, Uri: The Surgical Strike to Humsafar
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   imdb_id           1629 non-null   object
#  1   poster_path       1526 non-null   object
#  2   wiki_link         1629 non-null   object
#  3   title_y           1629 non-null   object
#  4   original_title    1629 non-null   object
#  5   is_adult          1629 non-null   int64
#  6   year_of_release   1629 non-null   int64
#  7   runtime           1629 non-null   object
#  8   genres            1629 non-null   object
#  9   imdb_rating       1629 non-null   float64
#  10  imdb_votes        1629 non-null   int64
#  11  story             1609 non-null   object
#  12  summary           1629 non-null   object
#  13  tagline           557 non-null    object
#  14  actors            1624 non-null   object
#  15  wins_nominations  707 non-null    object
# ...

# %%
movie.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movie['is_adult']
# Out:
# title_x
# Uri: The Surgical Strike                0
# Battalion 609                           0
# The Accidental Prime Minister (film)    0
# Why Cheat India                         0
# Evening Shadows                         0
#                                        ..
# Tera Mera Saath Rahen                   0
# Yeh Zindagi Ka Safar                    0
# Sabse Bada Sukh                         0
# Daaka                                   0
# Humsafar                                0
# Name: is_adult, Length: 1629, dtype: int64

# %%
movie.isnull().sum()
# Out:
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# Using List

student = {
 'name':['Uday','Mansi','Seema'],   
 'Iq':[10,20,30],
 'package':[10,20,30]
 }

student = pd.DataFrame(student)
student
# student.rename(columns = {'Uday':"Uday's"},inplace=True)
# student/
# Out:
#     name  Iq  package
# 0   Uday  10       10
# 1  Mansi  20       20
# 2  Seema  30       30

# %%
vk = pd.read_csv('kohli_ipl.csv')

# %%
vk['runs'].sum(axis=0)
# Out:
# 6634

# %%
student.sum(axis=1)
# Out:
# C:\Users\uday.sharma\AppData\Local\Temp\ipykernel_16992\3775440396.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   student.sum(axis=1)
# 0    20
# 1    40
# 2    60
# dtype: int64

# %%
ipl.iloc[:,:2]
# Out:
#           ID        City
# 0    1312200   Ahmedabad
# 1    1312199   Ahmedabad
# 2    1312198     Kolkata
# 3    1312197     Kolkata
# 4    1304116      Mumbai
# ..       ...         ...
# 945   335986     Kolkata
# 946   335985      Mumbai
# 947   335984       Delhi
# 948   335983  Chandigarh
# 949   335982   Bangalore
#
# [950 rows x 2 columns]

# %%
ipl[['ID','City']].head()
# Out:
#         ID       City
# 0  1312200  Ahmedabad
# 1  1312199  Ahmedabad
# 2  1312198    Kolkata
# 3  1312197    Kolkata
# 4  1304116     Mumbai

# %%
student.set_index('name',inplace=True)

# %%
movie.iloc[0:5:2]
# Out:
#                                         imdb_id  \
# title_x
# Uri: The Surgical Strike              tt8291224
# The Accidental Prime Minister (film)  tt6986710
# Evening Shadows                       tt6028796
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Evening Shadows                                                                     NaN
#
#                                                                               wiki_link  \
# title_x
# Uri: The Surgical Strike              https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# The Accidental Prime Minister (film)  https://en.wikipedia.org/wiki/The_Accidental_P...
# Evening Shadows                           https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movie.iloc[[0,4,5]]
# Out:
#                             imdb_id  \
# title_x
# Uri: The Surgical Strike  tt8291224
# Evening Shadows           tt6028796
# Soni (film)               tt6078866
#
#                                                                 poster_path  \
# title_x
# Uri: The Surgical Strike  https://upload.wikimedia.org/wikipedia/en/thum...
# Evening Shadows                                                         NaN
# Soni (film)               https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                   wiki_link  \
# title_x
# Uri: The Surgical Strike  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Evening Shadows               https://en.wikipedia.org/wiki/Evening_Shadows
# Soni (film)                       https://en.wikipedia.org/wiki/Soni_(film)
#
#                                            title_y            original_title  \
# title_x
# Uri: The Surgical Strike  Uri: The Surgical Strike  Uri: The Surgical Strike
# ...

# %%
movie.loc[:'Why Cheat India':2]
# Out:
#                                         imdb_id  \
# title_x
# Uri: The Surgical Strike              tt8291224
# The Accidental Prime Minister (film)  tt6986710
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                               wiki_link  \
# title_x
# Uri: The Surgical Strike              https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# The Accidental Prime Minister (film)  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                                                             title_y  \
# title_x
# Uri: The Surgical Strike                   Uri: The Surgical Strike
# The Accidental Prime Minister (film)  The Accidental Prime Minister
#
# ...

# %%
movie.iloc[[0,6]]
# Out:
#                             imdb_id  \
# title_x
# Uri: The Surgical Strike  tt8291224
# Fraud Saiyaan             tt5013008
#
#                                                                 poster_path  \
# title_x
# Uri: The Surgical Strike  https://upload.wikimedia.org/wikipedia/en/thum...
# Fraud Saiyaan             https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                   wiki_link  \
# title_x
# Uri: The Surgical Strike  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Fraud Saiyaan                   https://en.wikipedia.org/wiki/Fraud_Saiyaan
#
#                                            title_y            original_title  \
# title_x
# Uri: The Surgical Strike  Uri: The Surgical Strike  Uri: The Surgical Strike
# Fraud Saiyaan                        Fraud Saiyaan             Fraud Saiyyan
#
#                           is_adult  year_of_release runtime            genres  \
# title_x
# ...

# %%
movie.iloc[:3,:3]
# Out:
#                                         imdb_id  \
# title_x
# Uri: The Surgical Strike              tt8291224
# Battalion 609                         tt9472208
# The Accidental Prime Minister (film)  tt6986710
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                               wiki_link
# title_x
# Uri: The Surgical Strike              https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Battalion 609                               https://en.wikipedia.org/wiki/Battalion_609
# The Accidental Prime Minister (film)  https://en.wikipedia.org/wiki/The_Accidental_P...

# %%
movie.reset_index(inplace=True)

# %%
movie.loc[:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
# Find  All Final Winner
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl[ipl['MatchNumber'] == 'Final'][['WinningTeam']].value_counts()
# Out:
# WinningTeam
# Mumbai Indians           5
# Chennai Super Kings      4
# Kolkata Knight Riders    2
# Deccan Chargers          1
# Gujarat Titans           1
# Rajasthan Royals         1
# Sunrisers Hyderabad      1
# dtype: int64

# %%
# How many super over Finishes have Occured
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# How many csk won in Kolkata

ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# Toss winner is a match winner
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# Movies with higher rating than 8 and votes >10000

# %%
movie.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movie[(movie['imdb_rating'] > 8) & (movie['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# ACtion movie with rating higher than 7.5

# %%
movie.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movie[(movie['genres'].str.split('|').apply(lambda x:'Action' in x) ) & (movie['imdb_rating'] > 7.5)].shape[0]
# Out:
# 33

# %%
movie[(movie['genres'].str.contains('Action')) & (movie['imdb_rating'] > 7.5)].shape[0]
# Out:
# 33

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
movie.dropna(inplace=True)

# %%
movie.shape
# Out:
# (298, 18)

# %%
movie['Lead_Actor'] = movie['actors'].str.split('|').apply(lambda x :x[0])

# %%
movie.head(1)
# Out:
#       title_x    imdb_id                                        poster_path  \
# 11  Gully Boy  tt2395469  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                   wiki_link    title_y original_title  \
# 11  https://en.wikipedia.org/wiki/Gully_Boy  Gully Boy      Gully Boy
#
#     is_adult  year_of_release runtime       genres  imdb_rating  imdb_votes  \
# 11         0             2019     153  Drama|Music          8.2       22440
#
#                                                 story  \
# 11  Gully Boy is a film about a 22-year-old boy "M...
#
#                                               summary            tagline  \
# 11  A coming-of-age story based on the lives of st...  Apna Time Aayega!
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
#
#               release_date     Lead_Actor
# 11  14 February 2019 (USA)  Ranveer Singh

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl.value_counts()
# Out:
# ID       City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# ...

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
ipl[(ipl['MatchNumber'] == 'Final') | (ipl['MatchNumber'] == 'Qualifier 2') | (ipl['MatchNumber'] == 'Qualifier 1')]['Player_of_Match'].value_counts().head(1)
# Out:
# SK Raina    2
# Name: Player_of_Match, dtype: int64

# %%
ipl[~(ipl['MatchNumber'].str.isdigit())]['Player_of_Match'].value_counts().head(5)
# Out:
# KA Pollard      3
# F du Plessis    3
# SK Raina        3
# A Kumble        2
# MK Pandey       2
# Name: Player_of_Match, dtype: int64

# %%
# Toss Decision Plot

ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='TossDecision'>

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts().head(1)
# Out:
# KA Pollard    3
# Name: Player_of_Match, dtype: int64

# %%
movie.sort_values('title_x').head()
# Out:
#                   title_x    imdb_id  \
# 1039     1971 (2007 film)  tt0983990
# 912              3 Idiots  tt1187043
# 1135        36 China Town  tt0477252
# 1055             68 Pages  tt1151299
# 886   Aakrosh (2010 film)  tt1708453
#
#                                             poster_path  \
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# 912   https://upload.wikimedia.org/wikipedia/en/thum...
# 1135  https://upload.wikimedia.org/wikipedia/en/thum...
# 1055  https://upload.wikimedia.org/wikipedia/en/thum...
# 886   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link        title_y  \
# 1039     https://en.wikipedia.org/wiki/1971_(2007_film)           1971
# 912              https://en.wikipedia.org/wiki/3_Idiots       3 Idiots
# 1135        https://en.wikipedia.org/wiki/36_China_Town  36 China Town
# 1055             https://en.wikipedia.org/wiki/68_Pages       68 Pages
# ...

# %%
movie.sort_values(['year_of_release','title_x'],ascending=[False,True])[['year_of_release','title_x']]
# Out:
#       year_of_release                  title_x
# 37               2019        Article 15 (film)
# 11               2019                Gully Boy
# 87               2018                  Aiyaary
# 99               2018                 Baaghi 2
# 112              2018  Bhavesh Joshi Superhero
# ...               ...                      ...
# 1601             2001         Maya (2001 film)
# 1607             2001  Nayak (2001 Hindi film)
# 1621             2001                  Tum Bin
# 1573             2001      Yaadein (2001 film)
# 1623             2001                 Zubeidaa
#
# [298 rows x 2 columns]

# %%
batsman = pd.read_csv("batsman_runs_ipl.csv")

# %%
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman['Batting_rank'] = batsman['batsman_run'].rank(ascending=False)

# %%
batsman.sort_values('Batting_rank')
# Out:
#            batter  batsman_run  Batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
batsman.set_index('batter',inplace=True)

# %%
batsman.head()
# Out:
#                 batsman_run  Batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5

# %%
# # Replace Index
batsman.reset_index().set_index('Batting_rank')
# Out:
#                       batter  batsman_run
# Batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman.head()
# Out:
#                 batsman_run  Batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5

# %%
batsman.rename(index={'A Ashish Reddy':'Ashish Reddy'})
# Out:
#                batsman_run  Batting_rank
# batter
# Ashish Reddy           280         166.5
# A Badoni               161         226.0
# A Chandila               4         535.0
# A Chopra                53         329.0
# A Choudhary             25         402.5
# ...                    ...           ...
# Yash Dayal               0         594.0
# Yashpal Singh           47         343.0
# Younis Khan              3         547.5
# Yuvraj Singh          2754          27.0
# Z Khan                 117         256.0
#
# [605 rows x 2 columns]

# %%
len(batsman['batsman_run'].unique())
# Out:
# 317

# %%
ipl['Season'].unique()
# Out:
# ['2022', '2021', '2020/21', '2019', '2018', ..., '2012', '2011', '2009/10', '2009', '2007/08']
# Length: 15
# Categories (15, object): ['2007/08', '2009', '2009/10', '2011', ..., '2019', '2020/21', '2021', '2022']

# %%
ipl['Season'].nunique()
# Out:
# 15

# %%
ipl[ipl['Season'].notnull()]
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.notnull()
# Out:
#        ID  City  Date  Season  MatchNumber  Team1  Team2  Venue  TossWinner  \
# 0    True  True  True    True         True   True   True   True        True
# 1    True  True  True    True         True   True   True   True        True
# 2    True  True  True    True         True   True   True   True        True
# 3    True  True  True    True         True   True   True   True        True
# 4    True  True  True    True         True   True   True   True        True
# ..    ...   ...   ...     ...          ...    ...    ...    ...         ...
# 945  True  True  True    True         True   True   True   True        True
# 946  True  True  True    True         True   True   True   True        True
# 947  True  True  True    True         True   True   True   True        True
# 948  True  True  True    True         True   True   True   True        True
# 949  True  True  True    True         True   True   True   True        True
#
# ...

# %%
ipl.dropna(how='all')  # Sab jgah Empty hoga toh hi hatyga row
ipl.dropna(how='any') # Ek jgah Empty hoga toh hi hatyga row
ipl.dropna(subset=['City'])
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
student['Iq'].ffill
# Out:
# <bound method Series.ffill of name
# Uday     10
# Mansi    20
# Seema    30
# Name: Iq, dtype: int64>

# %%
student.drop_duplicates()
# Out:
#        Iq  package
# name
# Uday   10       10
# Mansi  20       20
# Seema  30       30

# %%
temp = pd.Series([1,1,1,2,3,3,3,3,2,2])

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 3    2
# 4    3
# dtype: int64

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
ipl[((ipl['Team1Players'].str.contains('V Kohli')) | (ipl['Team2Players'].str.contains('V Kohli'))) & (ipl['City'] == 'Delhi')].sort_values('Date',ascending=False).head(1)
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision SuperOver     WinningTeam WonBy  Margin method  \
# 208          bat         N  Delhi Capitals  Runs    16.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 208        S Dhawan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2
# 208  KN Ananthapadmanabhan

# %%
temp
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    3
# 5    3
# 6    3
# 7    3
# 8    2
# 9    2
# dtype: int64

# %%
def sigmoid(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.367879
# 1    1.367879
# 2    1.367879
# 3    1.135335
# 4    1.049787
# 5    1.049787
# 6    1.049787
# 7    1.049787
# 8    1.135335
# 9    1.135335
# dtype: float64
